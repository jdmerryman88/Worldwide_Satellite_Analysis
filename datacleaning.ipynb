# %%
# Dependencies and Setup
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import gmaps
import os

# File to Load 
satellite_data = "resources/UCS-Satellite-Database-8-1-2020.csv"


# Read satellite data file and store into Pandas DataFrames
satellite_df = pd.read_csv(satellite_data)


# View Data


satellite_df
# Out:
#                      Name of Satellite, Alternate Names  \
# 0     1HOPSAT-TD (1st-generation High Optical Perfor...
# 1                                                3Cat-1
# 2                                              Aalto-1
# 3                                              AAUSat-4
# 4                              ABS-2 (Koreasat-8, ST-3)
# ...                                                 ...
# 2782                                       Ziyuan 1-02C
# 2783                                        Ziyuan 1-2D
# 2784                                    Ziyuan 3 (ZY-3)
# 2785                                         Ziyuan 3-2
# 2786                                         Ziyuan 3-3
#
#      Current Official Name of Satellite Country/Org of UN Registry  \
# 0                               1HOPSAT                  NR (3/20)
# 1                                3Cat-1                         NR
# 2                               Aalto-1                    Finland
# 3                              AAUSat-4                    Denmark
# 4                                 ABS-2                         NR
# ...                                 ...                        ...
# 2782                       Ziyuan 1-02C                      China
# 2783                        Ziyuan 1-2D                 NR (11/19)
# 2784                           Ziyuan 3                      China
# 2785                         Ziyuan 3-2                      China
# 2786                         Ziyuan 3-3                  NR (7/20)
#
#      Country of Operator/Owner  \
# 0                          USA
# 1                        Spain
# 2                      Finland
# 3                      Denmark
# 4                Multinational
# ...                        ...
# 2782                     China
# 2783                     China
# 2784                     China
# 2785                     China
# 2786                     China
#
#                                          Operator/Owner       Users  \
# 0                                          Hera Systems  Commercial
# 1                  Universitat Politècnica de Catalunya       Civil
# 2                                      Aalto University       Civil
# 3                                 University of Aalborg       Civil
# 4                         Asia Broadcast Satellite Ltd.  Commercial
# ...                                                 ...         ...
# 2782  China Centre for Resources Satellite Data and ...  Government
# 2783  China Centre for Resources Satellite Data and ...  Government
# 2784  China Centre for Resources Satellite Data and ...  Government
# 2785  China Centre for Resources Satellite Data and ...  Government
# 2786  China Centre for Resources Satellite Data and ...  Government
#
#                      Purpose                       Detailed Purpose  \
# 0          Earth Observation                 Technology Development
# 1     Technology Development                                    NaN
# 2     Technology Development                                    NaN
# 3          Earth Observation  Automatic Identification System (AIS)
# 4             Communications                                    NaN
# ...                      ...                                    ...
# 2782       Earth Observation                                    NaN
# 2783       Earth Observation                                    NaN
# 2784       Earth Observation                                    NaN
# 2785       Earth Observation                                    NaN
# 2786       Earth Observation                                    NaN
#
#      Class of Orbit       Type of Orbit  ...  Unnamed: 57 Unnamed: 58  \
# 0               LEO  Non-Polar Inclined  ...          NaN         NaN
# 1               LEO                 NaN  ...          NaN         NaN
# 2               LEO                 NaN  ...          NaN         NaN
# 3               LEO     Sun-Synchronous  ...          NaN         NaN
# 4               GEO                 NaN  ...          NaN         NaN
# ...             ...                 ...  ...          ...         ...
# 2782            LEO     Sun-Synchronous  ...          NaN         NaN
# 2783            LEO     Sun-Synchronous  ...          NaN         NaN
# 2784            LEO     Sun-Synchronous  ...          NaN         NaN
# 2785            LEO     Sun-Synchronous  ...          NaN         NaN
# 2786            LEO     Sun-Synchronous  ...          NaN         NaN
#
#      Unnamed: 59  Unnamed: 60  Unnamed: 61 Unnamed: 62 Unnamed: 63  \
# 0            NaN          NaN          NaN         NaN         NaN
# 1            NaN          NaN          NaN         NaN         NaN
# 2            NaN          NaN          NaN         NaN         NaN
# 3            NaN          NaN          NaN         NaN         NaN
# 4            NaN          NaN          NaN         NaN         NaN
# ...          ...          ...          ...         ...         ...
# 2782         NaN          NaN          NaN         NaN         NaN
# 2783         NaN          NaN          NaN         NaN         NaN
# 2784         NaN          NaN          NaN         NaN         NaN
# 2785         NaN          NaN          NaN         NaN         NaN
# 2786         NaN          NaN          NaN         NaN         NaN
#
#      Unnamed: 64 Unnamed: 65 Unnamed: 66
# 0            NaN         NaN         NaN
# 1            NaN         NaN         NaN
# 2            NaN         NaN         NaN
# 3            NaN         NaN         NaN
# 4            NaN         NaN         NaN
# ...          ...         ...         ...
# 2782         NaN         NaN         NaN
# 2783         NaN         NaN         NaN
# 2784         NaN         NaN         NaN
# 2785         NaN         NaN         NaN
# 2786         NaN         NaN         NaN
#
# [2787 rows x 67 columns]

# %%
# Drop duplicate satellite names column. Only using current official satellite name
cleaned_data = satellite_df.drop(columns =['Name of Satellite, Alternate Names'])

#Drop Unnamed columns
col_index = 37
for x in range(30):
    cleaned_data = cleaned_data.drop(columns = [f'Unnamed: ' + str(col_index) ])    
    col_index = col_index + 1
    
  
cleaned_data
# Out:
#      Current Official Name of Satellite Country/Org of UN Registry  \
# 0                               1HOPSAT                  NR (3/20)
# 1                                3Cat-1                         NR
# 2                               Aalto-1                    Finland
# 3                              AAUSat-4                    Denmark
# 4                                 ABS-2                         NR
# ...                                 ...                        ...
# 2782                       Ziyuan 1-02C                      China
# 2783                        Ziyuan 1-2D                 NR (11/19)
# 2784                           Ziyuan 3                      China
# 2785                         Ziyuan 3-2                      China
# 2786                         Ziyuan 3-3                  NR (7/20)
#
#      Country of Operator/Owner  \
# 0                          USA
# 1                        Spain
# 2                      Finland
# 3                      Denmark
# 4                Multinational
# ...                        ...
# 2782                     China
# 2783                     China
# 2784                     China
# 2785                     China
# 2786                     China
#
#                                          Operator/Owner       Users  \
# 0                                          Hera Systems  Commercial
# 1                  Universitat Politècnica de Catalunya       Civil
# 2                                      Aalto University       Civil
# 3                                 University of Aalborg       Civil
# 4                         Asia Broadcast Satellite Ltd.  Commercial
# ...                                                 ...         ...
# 2782  China Centre for Resources Satellite Data and ...  Government
# 2783  China Centre for Resources Satellite Data and ...  Government
# 2784  China Centre for Resources Satellite Data and ...  Government
# 2785  China Centre for Resources Satellite Data and ...  Government
# 2786  China Centre for Resources Satellite Data and ...  Government
#
#                      Purpose                       Detailed Purpose  \
# 0          Earth Observation                 Technology Development
# 1     Technology Development                                    NaN
# 2     Technology Development                                    NaN
# 3          Earth Observation  Automatic Identification System (AIS)
# 4             Communications                                    NaN
# ...                      ...                                    ...
# 2782       Earth Observation                                    NaN
# 2783       Earth Observation                                    NaN
# 2784       Earth Observation                                    NaN
# 2785       Earth Observation                                    NaN
# 2786       Earth Observation                                    NaN
#
#      Class of Orbit       Type of Orbit  Longitude of GEO (degrees)  ...  \
# 0               LEO  Non-Polar Inclined                         0.0  ...
# 1               LEO                 NaN                         0.0  ...
# 2               LEO                 NaN                         0.0  ...
# 3               LEO     Sun-Synchronous                         0.0  ...
# 4               GEO                 NaN                        75.0  ...
# ...             ...                 ...                         ...  ...
# 2782            LEO     Sun-Synchronous                         0.0  ...
# 2783            LEO     Sun-Synchronous                         0.0  ...
# 2784            LEO     Sun-Synchronous                         0.0  ...
# 2785            LEO     Sun-Synchronous                         0.0  ...
# 2786            LEO     Sun-Synchronous                         0.0  ...
#
#                                                Comments Unnamed: 28  \
# 0     Pathfinder for planned earth observation const...         NaN
# 1                                        Student built.         NaN
# 2                 Technology development and education.         NaN
# 3                                   Carries AIS system.         NaN
# 4     32 C-band, 51 Ku-band, and 6 Ka-band transpond...         NaN
# ...                                                 ...         ...
# 2782  Can acquire high-resolution data through remot...         NaN
# 2783                              Hyperspectral imaging         NaN
# 2784                             Land survey satellite.         NaN
# 2785          Thought to be for intelligence gathering.         NaN
# 2786  Land survey satellite. Provide data for the co...         NaN
#
#       Source Used for Orbital Data  \
# 0                    JMSatcat/3_20
# 1                        Estimated
# 2                   JMSatcat/10_17
# 3                          Space50
# 4                            ZARYA
# ...                            ...
# 2782                     SC - ASCR
# 2783                JMSatcat/11_19
# 2784     www.spacedebris.net 12/12
# 2785                       Space50
# 2786                         ZARYA
#
#                                                  Source  \
# 0     https://spaceflightnow.com/2019/12/11/indias-5...
# 1     https://spaceflightnow.com/2018/11/29/indian-r...
# 2     https://directory.eoportal.org/web/eoportal/sa...
# 3     http://spaceflightnow.com/2016/04/26/soyuz-bla...
# 4     http://www.absatellite.net/satellite-fleet/?sa...
# ...                                                 ...
# 2782  http://www.tmcnet.com/usubmit/2011/12/22/60133...
# 2783  https://spaceflightnow.com/2019/09/12/china-la...
# 2784  http://www.spaceflightnow.com/news/n1201/09lon...
# 2785  http://spaceflightnow.com/2016/05/31/long-marc...
# 2786  https://spaceflightnow.com/2020/07/25/china-la...
#
#                    Unnamed: 31  \
# 0     https://www.herasys.com/
# 1                          NaN
# 2                          NaN
# 3                          NaN
# 4                          NaN
# ...                        ...
# 2782                       NaN
# 2783                       NaN
# 2784                       NaN
# 2785                       NaN
# 2786                       NaN
#
#                                                Source.1  \
# 0                                                   NaN
# 1                                                   NaN
# 2        http://www.planet4589.org/space/log/satcat.txt
# 3     http://space50.org/objekt.php?mot=2016-025E&ja...
# 4     http://www.zarya.info/Diaries/Launches/Launche...
# ...                                                 ...
# 2782     http://www.planet4589.org/space/log/satcat.txt
# 2783     http://www.planet4589.org/space/log/satcat.txt
# 2784  https://spacenews.com/china-launches-five-comm...
# 2785    https://www.planet4589.org/space/log/satcat.txt
# 2786       http://www.lib.cas.cz/space.40/2011/079A.HTM
#
#                                                Source.2  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4     http://www.absatellite.net/2010/10/13/asia-bro...
# ...                                                 ...
# 2782                                                NaN
# 2783                                                NaN
# 2784                                                NaN
# 2785  http://space50.org/objekt.php?mot=2016-033A&ja...
# 2786                                                NaN
#
#                                                Source.3 Source.4  Source.5
# 0                                                   NaN      NaN       NaN
# 1                                                   NaN      NaN       NaN
# 2                                                   NaN      NaN       NaN
# 3                                                   NaN      NaN       NaN
# 4     http://www.spacenews.com/article/satellite-tel...      NaN       NaN
# ...                                                 ...      ...       ...
# 2782                                                NaN      NaN       NaN
# 2783                                                NaN      NaN       NaN
# 2784                                                NaN      NaN       NaN
# 2785                                                NaN      NaN       NaN
# 2786                                                NaN      NaN       NaN
#
# [2787 rows x 36 columns]
